# %%
pip install dlib
# Out:
# Requirement already satisfied: dlib in c:\users\hkuma\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (19.24.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\hkuma\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\hkuma\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\hkuma\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opencv-python) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\hkuma\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import dlib
import cv2
import numpy as np

# %% [markdown]
# capture the frames from my primary camera

# %%
cap =cv2.VideoCapture(0)  #0 indicates the default camera

#face detector model
face_detector=dlib.get_frontal_face_detector()

#Capture frames continuously
while True:
    ret, frame = cap.read()
    if not ret or frame is None:
        print("Failed to grab frame")
        break

    frame = cv2.flip(frame, 1)  # Flip the frame horizontally for a mirror effect

    # RGB -> GrayScale
    gray= cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    faces = face_detector(gray)  # Detect faces in the grayscale image

    # Iterate through all the faces and draw rectangle around each face and also number it 
    i = 0
    for face in faces:
        # find the coordinates of the face
        x, y = face.left(), face.top()
        x1, y1 = face.right(), face.bottom()
        # draw the rectangle
        cv2.rectangle(frame, (x, y), (x1, y1), (0, 255, 0), 2)
        i = i + 1
        cv2.putText(frame, "Face num " + str(i), (x-10, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    cv2.imshow('frame', frame)

    if(cv2.waitKey(1) & 0xFF == ord('q')):
        break

cap.release()
cv2.destroyAllWindows()
