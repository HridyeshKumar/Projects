# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/110.1 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/110.1 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/110.1 kB 435.7 kB/s eta 0:00:01
#      --------------------------------- -- 102.4/110.1 kB 980.4 kB/s eta 0:00:01
#      ------------------------------------ 110.1/110.1 kB 798.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.1 MB 4.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/8.1 MB 7.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.1 MB 6.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/8.1 MB 5.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.1 MB 5.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.1 MB 5.6 MB/s eta 0:00:02
# ...

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.3 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/11.3 MB 4.2 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.3 MB 6.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/11.3 MB 5.4 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.3 MB 5.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.3 MB 4.8 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.3 MB 4.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.3 MB 4.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.3 MB 4.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/11.3 MB 3.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.3 MB 3.9 MB/s eta 0:00:03
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the data present in the TSV file
df=pd.read_csv("diabetese.tsv",sep="\t")
df.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     442 non-null    int64
#  1   SEX     442 non-null    int64
#  2   BMI     442 non-null    float64
#  3   BP      442 non-null    float64
#  4   S1      442 non-null    int64
#  5   S2      442 non-null    float64
#  6   S3      442 non-null    float64
#  7   S4      442 non-null    float64
#  8   S5      442 non-null    float64
#  9   S6      442 non-null    int64
#  10  Y       442 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %%
#Let's find the average age of diabetic patients
mean_age=df['AGE'].mean()
print(f"Mean age is: {mean_age} years")
# Out:
# Mean age is: 48.51809954751131 years

# %%
#Variance
var_age=df['AGE'].var()
print(f"Variance in age is: {var_age} years")
# Out:
# Variance in age is: 171.84661043904742 years

# %%
#Standard Deviation
std_age=df['AGE'].std()
print(f"Standard Deviation in age is: {std_age} years")
# Out:
# Standard Deviation in age is: 13.109027822041092 years

# %%
#Boxplot for Age
plt.figure(figsize=(2,6))
plt.boxplot(df['AGE'],showmeans=True)
plt.grid(color='gray', linestyle='dotted')
plt.xlabel('Age')
plt.ylabel('Years')
plt.show()

# %%
#Boxplotting for BMI
plt.figure(figsize=(6,2))
plt.boxplot(df['BMI'],vert=False,showmeans=True)
plt.grid(color='gray', linestyle='dotted')
plt.xlabel('Value')
plt.ylabel('BMI')
plt.show()

# %%
#Boxplotting for BP
plt.figure(figsize=(6,2))
plt.boxplot(df['BP'],vert=False,showmeans=True)
plt.grid(color='gray', linestyle='dotted')
plt.xlabel('Value')
plt.ylabel('BP')
plt.show()

# %%
#I want to understand what age of the patients are mostly diabetic

#We can create histograms for the same
df['AGE'].hist(bins=12)
plt.title('Age Distribution of Diabetic Patients')
plt.xlabel('Age Range')
plt.ylabel('Number of Patients')
plt.show()

# %%
df['BMI'].hist(bins=12)
plt.title('BMI Distribution of Diabetic Patients')
plt.xlabel('BMI Range')
plt.ylabel('Number of Patients')
plt.show()

# %%
study_hours=[2,3,1,4,2,5,4,6,3,5]
exam_scores=[70,80,60,85,75,90,88,92,80,95]
plt.scatter(study_hours, exam_scores,color='blue', marker='o')
plt.xlabel('Study Hours')
plt.ylabel('Exam Scores')   
plt.title('Scatter plot: Study Hours vs Exam Scores')
plt.show()

# %%
plt.scatter(df['BMI'], df['Y'], color='blue')

plt.xlabel('BMI')
plt.ylabel('Diabetes Progression')
plt.title('Scatter plot: BMI vs Diabetes Progression')
plt.show()

# %%
plt.scatter(df['S5'], df['Y'], color='blue')

plt.xlabel('S5 blood type')
plt.ylabel('Diabetes Progression')
plt.title('Scatter plot: S5 vs Diabetes Progression')
plt.show()
